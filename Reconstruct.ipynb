# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from scipy.spatial.distance import cdist
import numpy as np
import os

import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score
from sklearn.preprocessing import MinMaxScaler

import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook'

# %% [markdown]
# ### Loading mixed playlist and Datasets as dictionaries

# %%
# Load the datasets
mixed_playlist = pd.read_csv('data/mixed_playlist.csv')

# %%
# Loading Users Dataset
# Base directory where the folders with CSV files are located
base_dir = 'data/recovered_data/'

# Initialize a dictionary to store the DataFrames with the filename as the key
dataframes = {}

# Loop through each folder in the base directory
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)
    
    # Check if the path is actually a directory
    if os.path.isdir(folder_path):
        
        # Loop through each file in the folder
        for file_name in os.listdir(folder_path):
            
            # Construct the full file path
            file_path = os.path.join(folder_path, file_name)
            
            # Check if the file is a CSV
            if file_name.endswith('.csv'):
                
                # Read the CSV file and store the DataFrame
                df = pd.read_csv(file_path)
                
                # Use the filename without extension as the dictionary key
                dataframe_key = os.path.splitext(file_name)[0]
                dataframes[dataframe_key] = df

# At this point, you have a dictionary with each DataFrame accessible by its key
# For example, to access the DataFrame for 'user_alpha_2016', you would use:
# dataframes['user_alpha_2016']

# %%
# Exploring recovered data
# dataframes['user_alpha_2016']

# %%
mixed_playlist
# Out:
#                                                    name  \
# 0     Variations on a Polish Theme, Op. 10: No. 5 An...
# 1     Je vous trouve un charme fou - En duo avec Gaë...
# 2                                              Me Gusta
# 3                                  L’amour en Solitaire
# 4                                        Goodnight Moon
# ...                                                 ...
# 3894                                 My Funny Valentine
# 3895                                        Petit homme
# 3896              Neo-Tokyo - Dance With The Dead Remix
# 3897                                               Fool
# 3898                           Sea, Sex And Sun - Remix
#
#                                       album             artist release_date  \
# 0          Szymanowski: Piano Works, Vol. 2  Karol Szymanowski   06/12/1996
# 1     Il suffit d'y croire (Version deluxe)              Hoshi   2018-11-30
# 2                               On ira où ?                DTF   2019-10-11
# 3                      Petite Amie (Deluxe)   Juliette Armanet   2018-02-02
# 4                                     Volta    Boogie Belgique   2016-09-23
# ...                                     ...                ...          ...
# 3894                           Undercurrent         Bill Evans         1962
# 3895            Earthquake (Edition Deluxe)            Kolinga   2019-04-05
# 3896   Dreams of Neo-Tokyo (Deluxe Edition)          Scandroid   2017-03-31
# 3897                                   Fool              Antis   2017-12-15
# 3898               Sea, Sex And Sun (Remix)   Serge Gainsbourg   29/04/2022
#
#       length  popularity  acousticness  danceability   energy  \
# 0      76933          53      0.996000         0.329  0.00695
# 1     172626          62      0.622000         0.615  0.59900
# 2     175269          72      0.413000         0.834  0.73400
# 3     175266           0      0.404000         0.797  0.50600
# 4     264735          53      0.061600         0.788  0.67500
# ...      ...         ...           ...           ...      ...
# 3894  324133          41      0.992000         0.529  0.13300
# 3895  185506           0      0.942000         0.417  0.19600
# 3896  352105          51      0.000016         0.467  0.95400
# 3897  154826          16      0.045300         0.589  0.79200
# 3898  229626          33      0.161000         0.724  0.73600
#
#       instrumentalness  ...  speechiness    tempo  valence  time_signature  \
# 0             0.866000  ...       0.0448   70.295    0.238               4
# 1             0.000008  ...       0.2530   86.976    0.626               4
# 2             0.000040  ...       0.3410   89.989    0.356               4
# 3             0.000153  ...       0.0327  128.027    0.539               4
# 4             0.711000  ...       0.0318  107.993    0.525               4
# ...                ...  ...          ...      ...      ...             ...
# 3894          0.922000  ...       0.0575  115.924    0.585               4
# 3895          0.001700  ...       0.0871   76.774    0.505               3
# 3896          0.908000  ...       0.0414  122.004    0.061               4
# 3897          0.008480  ...       0.0569  182.051    0.658               4
# 3898          0.004440  ...       0.0455  118.989    0.384               4
#
#       key  mode                                   uri  release_year top_year  \
# 0      11     0  spotify:track:3bcdLMrAxrfn5dxInjIdI2          1996  unknown
# 1       1     1  spotify:track:0C2yaSWVgCUiiqPyYxSOkd          2018     2022
# 2       6     0  spotify:track:6P3FBaZfUjeWYExU2ShaPZ          2019     2020
# 3       5     0  spotify:track:2tn51grfchxArwPXeXkoX5          2018     2018
# 4       7     0  spotify:track:2rvo9Ddv18aRV0OJldhWTf          2016     2020
# ...   ...   ...                                   ...           ...      ...
# 3894    0     0  spotify:track:5jIvud0zWXDpINxFqXfbpv          1962     2020
# 3895    4     0  spotify:track:6ejfdgCwtSp7g2kl9RMAT1          2019     2020
# 3896    0     0  spotify:track:44K1GCbNLf1NHlCaLaYONk          2017     2021
# 3897    6     1  spotify:track:4osf9MVY2OuJOoYXfTDzPP          2017     2018
# 3898    5     1  spotify:track:6lSpiJ04W6Wm9tEgqVSBwE          2022  unknown
#
#          user
# 0     unknown
# 1       delta
# 2       gamma
# 3       gamma
# 4       alpha
# ...       ...
# 3894     beta
# 3895    delta
# 3896    dzeta
# 3897     beta
# 3898  unknown
#
# [3899 rows x 22 columns]

# %% [markdown]
# ### Prepare mixed_playlist data to being processed

# %%
# To display categories "Users" that exists in the column user
num_categories = mixed_playlist.user.unique()
num_categories
# Out:
# array(['unknown', 'delta', 'gamma', 'alpha', 'dzeta', 'beta', 'epsilon'],
#       dtype=object)

# %% [markdown]
# ##### Converting categories "users" in numbers that serves as index
#
# 'unknown' = 0
#  'delta' = 1
# 'gamma' = 2
# 'alpha' = 3
#  'dzeta' = 4
#  'beta' = 5
# 'epsilon' = 6

# %%
mapping = {'unknown': 0, 'delta': 1, 'gamma': 2, 'alpha': 3, 'dzeta': 4, 'beta': 5, 'epsilon': 6}
mixed_playlist['user'] = mixed_playlist['user'].replace(mapping)
mixed_playlist.user
# Out:
# 0       0
# 1       1
# 2       2
# 3       2
# 4       3
#        ..
# 3894    5
# 3895    1
# 3896    4
# 3897    5
# 3898    0
# Name: user, Length: 3899, dtype: int64

# %%
# Replace 'unknown' values in 'top_year' column with 0
mixed_playlist['top_year'] = mixed_playlist['top_year'].replace('unknown', 0)

mixed_playlist.top_year
# Out:
# 0          0
# 1       2022
# 2       2020
# 3       2018
# 4       2020
#         ...
# 3894    2020
# 3895    2020
# 3896    2021
# 3897    2018
# 3898       0
# Name: top_year, Length: 3890, dtype: object

# %%
mixed_playlist.info()
mixed_playlist.dropna(inplace=True)

# display the descriptive statistics of numeric variables
mixed_playlist.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3890 entries, 0 to 3898
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3890 non-null   object
#  1   album             3890 non-null   object
#  2   artist            3890 non-null   object
#  3   release_date      3890 non-null   object
#  4   length            3890 non-null   int64
#  5   popularity        3890 non-null   int64
#  6   acousticness      3890 non-null   float64
#  7   danceability      3890 non-null   float64
#  8   instrumentalness  3890 non-null   float64
#  9   liveness          3890 non-null   float64
#  10  speechiness       3890 non-null   float64
#  11  tempo             3890 non-null   float64
#  12  valence           3890 non-null   float64
#  13  time_signature    3890 non-null   int64
#  14  key               3890 non-null   int64
#  15  mode              3890 non-null   int64
#  16  uri               3890 non-null   object
#  17  release_year      3890 non-null   int64
#  18  top_year          3890 non-null   object
#  19  user              3890 non-null   int64
# dtypes: float64(7), int64(7), object(6)
# memory usage: 638.2+ KB
#              length   popularity  acousticness  danceability  \
# count  3.890000e+03  3890.000000   3890.000000   3890.000000
# mean   2.444187e+05    32.005398      0.425120      0.554521
# std    1.045747e+05    24.920088      0.363021      0.192029
# min    3.105300e+04     0.000000      0.000001      0.000000
# 25%    1.880332e+05     1.000000      0.058025      0.424250
# 50%    2.242485e+05    34.000000      0.339000      0.575000
# 75%    2.744900e+05    51.000000      0.793000      0.701000
# max    1.921683e+06    91.000000      0.996000      0.971000
#
#        instrumentalness     liveness  speechiness        tempo      valence  \
# count       3890.000000  3890.000000  3890.000000  3890.000000  3890.000000
# mean           0.296768     0.167134     0.085179   115.826347     0.384641
# std            0.386456     0.143656     0.092698    28.662454     0.254691
# min            0.000000     0.017900     0.000000     0.000000     0.000000
# 25%            0.000004     0.094500     0.036800    94.546750     0.161000
# 50%            0.005730     0.112000     0.047000   115.151500     0.355000
# 75%            0.773000     0.172000     0.086775   131.986750     0.572000
# max            0.995000     0.991000     0.952000   209.596000     0.981000
#
#        time_signature          key         mode  release_year         user
# count     3890.000000  3890.000000  3890.000000   3890.000000  3890.000000
# mean         3.873779     5.295630     0.466838   2012.748072     3.357326
# std          0.465588     3.507038     0.498963     10.418784     1.844656
# min          0.000000     0.000000     0.000000   1957.000000     0.000000
# 25%          4.000000     2.000000     0.000000   2012.000000     2.000000
# 50%          4.000000     5.000000     0.000000   2016.000000     3.000000
# 75%          4.000000     8.000000     1.000000   2018.000000     5.000000
# max          5.000000    11.000000     1.000000   2022.000000     6.000000

# %%
# display the correlation matrix between numeric variables
corr = mixed_playlist.corr(numeric_only = True)
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_35dec_row0_col0, #T_35dec_row1_col1, #T_35dec_row2_col2, #T_35dec_row3_col3, #T_35dec_row4_col4, #T_35dec_row5_col5, #T_35dec_row6_col6, #T_35dec_row7_col7, #T_35dec_row8_col8, #T_35dec_row9_col9, #T_35dec_row10_col10, #T_35dec_row11_col11, #T_35dec_row12_col12, #T_35dec_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col2, #T_35dec_row5_col3, #T_35dec_row12_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_35dec_row0_col3, #T_35dec_row10_col12 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_35dec_row0_col5, #T_35dec_row2_col8, #T_35dec_row6_col11, #T_35dec_row9_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col6, #T_35dec_row1_col7, #T_35dec_row1_col12, #T_35dec_row9_col13, #T_35dec_row11_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col7, #T_35dec_row5_col0, #T_35dec_row7_col13, #T_35dec_row8_col10 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col8, #T_35dec_row6_col1, #T_35dec_row12_col10 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col9, #T_35dec_row13_col11 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col10, #T_35dec_row9_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col11, #T_35dec_row5_col12, #T_35dec_row6_col10, #T_35dec_row7_col2, #T_35dec_row7_col10, #T_35dec_row10_col0, #T_35dec_row13_col10 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_35dec_row0_col13, #T_35dec_row7_col5, #T_35dec_row9_col10, #T_35dec_row9_col11, #T_35dec_row12_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_35dec_row1_col0, #T_35dec_row8_col2, #T_35dec_row12_col5, #T_35dec_row12_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_35dec_row1_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_35dec_row1_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_35dec_row1_col4, #T_35dec_row10_col9, #T_35dec_row11_col9 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_35dec_row1_col5, #T_35dec_row3_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_35dec_row1_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_35dec_row1_col8, #T_35dec_row10_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_35dec_row1_col9, #T_35dec_row4_col12, #T_35dec_row5_col9, #T_35dec_row10_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_35dec_row1_col10, #T_35dec_row4_col11, #T_35dec_row5_col11, #T_35dec_row12_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_35dec_row1_col11, #T_35dec_row10_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_35dec_row1_col13, #T_35dec_row8_col13 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_35dec_row2_col0, #T_35dec_row3_col1, #T_35dec_row13_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_35dec_row2_col1, #T_35dec_row2_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_35dec_row2_col3, #T_35dec_row2_col5, #T_35dec_row2_col7, #T_35dec_row2_col9, #T_35dec_row2_col12, #T_35dec_row2_col13, #T_35dec_row3_col2, #T_35dec_row4_col1, #T_35dec_row4_col6, #T_35dec_row4_col8, #T_35dec_row8_col0, #T_35dec_row8_col4, #T_35dec_row10_col11, #T_35dec_row11_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_35dec_row2_col4, #T_35dec_row3_col6, #T_35dec_row8_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_35dec_row2_col6, #T_35dec_row7_col11, #T_35dec_row13_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_35dec_row2_col11, #T_35dec_row3_col5, #T_35dec_row3_col11, #T_35dec_row10_col5, #T_35dec_row11_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_35dec_row3_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_35dec_row3_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_35dec_row3_col8 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_35dec_row3_col9 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_35dec_row3_col10, #T_35dec_row8_col1, #T_35dec_row9_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_35dec_row3_col12, #T_35dec_row11_col2, #T_35dec_row11_col3, #T_35dec_row12_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_35dec_row3_col13 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_35dec_row4_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_35dec_row4_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_35dec_row4_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_35dec_row4_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_35dec_row4_col7, #T_35dec_row13_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_35dec_row4_col9, #T_35dec_row8_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_35dec_row4_col10, #T_35dec_row11_col12 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_35dec_row4_col13, #T_35dec_row10_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_35dec_row5_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_35dec_row5_col2, #T_35dec_row7_col12 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_35dec_row5_col4, #T_35dec_row9_col12 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_35dec_row5_col6, #T_35dec_row10_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_35dec_row5_col7, #T_35dec_row6_col7, #T_35dec_row7_col9, #T_35dec_row12_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_35dec_row5_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_35dec_row5_col10, #T_35dec_row6_col0, #T_35dec_row7_col1, #T_35dec_row8_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_35dec_row5_col13, #T_35dec_row9_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_35dec_row6_col2, #T_35dec_row7_col0, #T_35dec_row9_col7, #T_35dec_row13_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_35dec_row6_col3 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_35dec_row6_col4, #T_35dec_row11_col1, #T_35dec_row11_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_35dec_row6_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_35dec_row6_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_35dec_row6_col9 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_35dec_row6_col12, #T_35dec_row12_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_35dec_row6_col13 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_35dec_row7_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_35dec_row7_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_35dec_row7_col6, #T_35dec_row8_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_35dec_row7_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_35dec_row8_col3 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_35dec_row8_col5, #T_35dec_row9_col4, #T_35dec_row13_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_35dec_row8_col9, #T_35dec_row13_col12 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_35dec_row9_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_35dec_row9_col6, #T_35dec_row11_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_35dec_row9_col8 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_35dec_row10_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_35dec_row10_col6, #T_35dec_row13_col9 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_35dec_row10_col13, #T_35dec_row13_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_35dec_row11_col0, #T_35dec_row11_col13 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_35dec_row11_col4, #T_35dec_row12_col13 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_35dec_row12_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_35dec_row12_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_35dec_row12_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_35de

# %%
correlation_matrix = mixed_playlist.corr()
# You can set a threshold for correlation values and remove features with high correlation
threshold = 0.7  # Adjust this threshold as needed
highly_correlated_features = set()
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname = correlation_matrix.columns[i]
            highly_correlated_features.add(colname)

mixed_playlist.drop(highly_correlated_features, axis=1, inplace=True)
# Out:
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_15604\1644523848.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
mixed_playlist
# Out:
#                                                    name  \
# 0     Variations on a Polish Theme, Op. 10: No. 5 An...
# 1     Je vous trouve un charme fou - En duo avec Gaë...
# 2                                              Me Gusta
# 3                                  L’amour en Solitaire
# 4                                        Goodnight Moon
# ...                                                 ...
# 3894                                 My Funny Valentine
# 3895                                        Petit homme
# 3896              Neo-Tokyo - Dance With The Dead Remix
# 3897                                               Fool
# 3898                           Sea, Sex And Sun - Remix
#
#                                       album             artist release_date  \
# 0          Szymanowski: Piano Works, Vol. 2  Karol Szymanowski   06/12/1996
# 1     Il suffit d'y croire (Version deluxe)              Hoshi   2018-11-30
# 2                               On ira où ?                DTF   2019-10-11
# 3                      Petite Amie (Deluxe)   Juliette Armanet   2018-02-02
# 4                                     Volta    Boogie Belgique   2016-09-23
# ...                                     ...                ...          ...
# 3894                           Undercurrent         Bill Evans         1962
# 3895            Earthquake (Edition Deluxe)            Kolinga   2019-04-05
# 3896   Dreams of Neo-Tokyo (Deluxe Edition)          Scandroid   2017-03-31
# 3897                                   Fool              Antis   2017-12-15
# 3898               Sea, Sex And Sun (Remix)   Serge Gainsbourg   29/04/2022
#
#       length  popularity  acousticness  danceability  instrumentalness  \
# 0      76933          53      0.996000         0.329          0.866000
# 1     172626          62      0.622000         0.615          0.000008
# 2     175269          72      0.413000         0.834          0.000040
# 3     175266           0      0.404000         0.797          0.000153
# 4     264735          53      0.061600         0.788          0.711000
# ...      ...         ...           ...           ...               ...
# 3894  324133          41      0.992000         0.529          0.922000
# 3895  185506           0      0.942000         0.417          0.001700
# 3896  352105          51      0.000016         0.467          0.908000
# 3897  154826          16      0.045300         0.589          0.008480
# 3898  229626          33      0.161000         0.724          0.004440
#
#       liveness  speechiness    tempo  valence  time_signature  key  mode  \
# 0       0.0906       0.0448   70.295    0.238               4   11     0
# 1       0.1920       0.2530   86.976    0.626               4    1     1
# 2       0.1130       0.3410   89.989    0.356               4    6     0
# 3       0.2550       0.0327  128.027    0.539               4    5     0
# 4       0.1000       0.0318  107.993    0.525               4    7     0
# ...        ...          ...      ...      ...             ...  ...   ...
# 3894    0.1100       0.0575  115.924    0.585               4    0     0
# 3895    0.1250       0.0871   76.774    0.505               3    4     0
# 3896    0.0856       0.0414  122.004    0.061               4    0     0
# 3897    0.1020       0.0569  182.051    0.658               4    6     1
# 3898    0.1620       0.0455  118.989    0.384               4    5     1
#
#                                        uri  release_year top_year  user
# 0     spotify:track:3bcdLMrAxrfn5dxInjIdI2          1996        0     0
# 1     spotify:track:0C2yaSWVgCUiiqPyYxSOkd          2018     2022     1
# 2     spotify:track:6P3FBaZfUjeWYExU2ShaPZ          2019     2020     2
# 3     spotify:track:2tn51grfchxArwPXeXkoX5          2018     2018     2
# 4     spotify:track:2rvo9Ddv18aRV0OJldhWTf          2016     2020     3
# ...                                    ...           ...      ...   ...
# 3894  spotify:track:5jIvud0zWXDpINxFqXfbpv          1962     2020     5
# 3895  spotify:track:6ejfdgCwtSp7g2kl9RMAT1          2019     2020     1
# 3896  spotify:track:44K1GCbNLf1NHlCaLaYONk          2017     2021     4
# 3897  spotify:track:4osf9MVY2OuJOoYXfTDzPP          2017     2018     5
# 3898  spotify:track:6lSpiJ04W6Wm9tEgqVSBwE          2022        0     0
#
# [3890 rows x 20 columns]

# %%
# It is considered Irrelevant features every description or string that does not contribute in understanding the nature of the song
irrelevant_features = ['name', 'album', 'artist','release_date','uri']  # Modify this list with your irrelevant feature names
mixed_playlist.drop(irrelevant_features, axis=1, inplace=True)

# %%
# Feauture Scaling

scaler = MinMaxScaler()
mixed_playlist_scaled = scaler.fit_transform(mixed_playlist)
mixed_playlist = pd.DataFrame(mixed_playlist_scaled, columns=mixed_playlist.columns)

mixed_playlist
# Out:
#         length  popularity  acousticness  danceability  instrumentalness  \
# 0     0.024267    0.582418      1.000000      0.338826          0.870352
# 1     0.074881    0.681319      0.624497      0.633368          0.000008
# 2     0.076279    0.791209      0.414658      0.858908          0.000040
# 3     0.076278    0.000000      0.405622      0.820803          0.000154
# 4     0.123600    0.582418      0.061846      0.811535          0.714573
# ...        ...         ...           ...           ...               ...
# 3885  0.155017    0.450549      0.995984      0.544799          0.926633
# 3886  0.081694    0.000000      0.945783      0.429454          0.001709
# 3887  0.169812    0.560440      0.000015      0.480947          0.912563
# 3888  0.065467    0.175824      0.045481      0.606591          0.008523
# 3889  0.105030    0.362637      0.161645      0.745623          0.004462
#
#       liveness  speechiness     tempo   valence  time_signature       key  \
# 0     0.074710     0.047059  0.335383  0.242610             0.8  1.000000
# 1     0.178913     0.265756  0.414970  0.638124             0.8  0.090909
# 2     0.097729     0.358193  0.429345  0.362895             0.8  0.545455
# 3     0.243654     0.034349  0.610827  0.549439             0.8  0.454545
# 4     0.084370     0.033403  0.515244  0.535168             0.8  0.636364
# ...        ...          ...       ...       ...             ...       ...
# 3885  0.094646     0.060399  0.553083  0.596330             0.8  0.000000
# 3886  0.110061     0.091492  0.366295  0.514781             0.6  0.363636
# 3887  0.069571     0.043487  0.582091  0.062181             0.8  0.000000
# 3888  0.086425     0.059769  0.868581  0.670744             0.8  0.545455
# 3889  0.148083     0.047794  0.567706  0.391437             0.8  0.454545
#
#       mode  release_year  top_year      user
# 0      0.0      0.600000  0.000000  0.000000
# 1      1.0      0.938462  1.000000  0.166667
# 2      0.0      0.953846  0.999011  0.333333
# 3      0.0      0.938462  0.998022  0.333333
# 4      0.0      0.907692  0.999011  0.500000
# ...    ...           ...       ...       ...
# 3885   0.0      0.076923  0.999011  0.833333
# 3886   0.0      0.953846  0.999011  0.166667
# 3887   0.0      0.923077  0.999505  0.666667
# 3888   1.0      0.923077  0.998022  0.833333
# 3889   1.0      1.000000  0.000000  0.000000
#
# [3890 rows x 15 columns]

# %%
# K-Means clustering
X = mixed_playlist.values
model = KMeans(
    n_clusters = 6, # 6 clusters referred to 6 users 'delta': 1, 'gamma': 2, 'alpha': 3, 'dzeta': 4, 'beta': 5, 'epsilon': 6
    n_init = 'auto', # multiple attempt with different initial centroids
    random_state = 1, # fix ramdom state to guarantee reproducibility
    verbose = 1 # output log
)
model.fit(X)
# Out:
# Initialization complete
# Iteration 0, inertia 3548.7558486529265.
# Iteration 1, inertia 2296.255249186367.
# Iteration 2, inertia 2178.2526012553294.
# Iteration 3, inertia 2134.0134837180403.
# Iteration 4, inertia 2113.306456790444.
# Iteration 5, inertia 2099.979010165711.
# Iteration 6, inertia 2094.286963700861.
# Iteration 7, inertia 2092.852732574386.
# Iteration 8, inertia 2092.427159946258.
# Iteration 9, inertia 2092.352060016224.
# Iteration 10, inertia 2092.269091746777.
# Iteration 11, inertia 2092.2402103933073.
# Converged at iteration 11: center shift 3.251393255717938e-06 within tolerance 6.816383810380061e-06.
# KMeans(n_clusters=6, n_init='auto', random_state=1, verbose=1)

# %%
# obtain the cluster centers
model.cluster_centers_
# Out:
# array([[ 1.07387768e-01,  3.64806482e-01,  7.17242490e-01,
#          5.58804011e-01,  4.92461782e-02,  1.54129107e-01,
#          9.16826600e-02,  5.56580255e-01,  4.03577765e-01,
#          7.57585644e-01,  4.77383954e-01, -1.66533454e-16,
#          8.27330907e-01,  9.54594082e-01,  3.41761827e-01],
#        [ 1.27333722e-01,  2.84910212e-01,  1.10252973e-01,
#          5.70759966e-01,  7.99528128e-01,  1.55922360e-01,
#          6.58648673e-02,  5.82160689e-01,  2.88763643e-01,
#          7.87195122e-01,  4.69235033e-01,  1.00000000e+00,
#          9.05581614e-01,  9.86548877e-01,  6.60569106e-01],
#        [ 1.27378935e-01,  3.12969123e-01,  5.26431331e-01,
#          4.51871467e-01,  8.39522494e-01,  1.28344219e-01,
#          5.46526455e-02,  5.50011691e-01,  2.19827919e-01,
#          7.58478605e-01,  5.10012966e-01, -3.88578059e-16,
#          8.62245520e-01,  9.52943924e-01,  6.55573164e-01],
#        [ 1.03438068e-01,  3.77121674e-01,  1.49085573e-01,
#          6.78173415e-01,  6.64341340e-02,  1.69559091e-01,
#          1.21910119e-01,  5.70065952e-01,  5.39084043e-01,
#          7.96867470e-01,  5.69550931e-01, -1.72084569e-15,
#          8.94124189e-01,  9.97350232e-01,  6.14859438e-01],
#        [ 1.05589880e-01,  3.92615094e-01,  2.41277062e-01,
#          6.58263201e-01,  2.30081458e-02,  1.71077650e-01,
#          1.15382871e-01,  5.53508347e-01,  5.15201269e-01,
#          7.91629956e-01,  4.20204245e-01,  1.00000000e+00,
#          8.55032192e-01,  9.87411600e-01,  5.54698972e-01],
#        [ 1.19489234e-01,  3.17374005e-01,  8.78491389e-01,
#          4.24197770e-01,  4.51769355e-01,  1.27393258e-01,
#          5.13932556e-02,  5.08190815e-01,  2.22707477e-01,
#          7.45517241e-01,  4.31191223e-01,  1.00000000e+00,
#          8.09575597e-01,  9.48693680e-01,  5.56609195e-01]])
